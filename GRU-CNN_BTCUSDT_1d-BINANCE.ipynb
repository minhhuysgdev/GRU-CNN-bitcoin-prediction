# %%
# Dự đoán Bi-GRU + CNN
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Bidirectional, GRU, Conv1D, MaxPooling1D, Dense, Dropout, Flatten
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# ===== Hàm xây dựng mô hình Bi-GRU + CNN =====
def build_bigru_cnn_model(input_shape):
    inputs = Input(shape=input_shape)
    x = Bidirectional(GRU(32, return_sequences=True))(inputs)
    x = Bidirectional(GRU(32, return_sequences=True))(x)

    x = Conv1D(filters=32, kernel_size=5, activation='selu', padding='same')(x)
    x = Conv1D(filters=16, kernel_size=5, activation='selu', padding='same')(x)
    x = MaxPooling1D(pool_size=2)(x)

    x = Flatten()(x)
    x = Dense(64, activation='relu')(x)
    x = Dropout(0.2)(x)
    x = Dense(1)(x)

    model = Model(inputs=inputs, outputs=x)
    model.compile(optimizer='adam', loss='mse')
    return model

# ===== Hàm đọc dữ liệu Bitcoin từ file CSV =====
def load_bitcoin_data_csv(path):
    df = pd.read_csv(path)
    columns_needed = ['Open', 'High', 'Low', 'Close', 'Volume', 'Taker Buy Base Volume', 'Taker Buy Quote Volume']
    for col in columns_needed:
        if col not in df.columns:
            raise ValueError(f"Thiếu cột '{col}' trong dữ liệu.")
    df = df[columns_needed].dropna()
    return df

# ===== Hàm chuẩn bị dữ liệu theo chuỗi thời gian =====
def prepare_data(df, time_steps=60):
    scaler_X = MinMaxScaler()
    data_X = scaler_X.fit_transform(df)

    scaler_y = MinMaxScaler()
    data_y = scaler_y.fit_transform(df[['Close']])

    X, y = [], []
    for i in range(time_steps, len(df)):
        X.append(data_X[i-time_steps:i])
        y.append(data_y[i])
    return np.array(X), np.array(y), scaler_X, scaler_y


# ===== Đọc và chuẩn bị dữ liệu =====
path = 'data/BTCUSDT-1d-BINANCE.csv'
data = load_bitcoin_data_csv(path)
X, y, scaler_X, scaler_y = prepare_data(data, time_steps=60)

# ===== Chia dữ liệu train/test =====
split = int(0.75 * len(X))
X_train, y_train = X[:split], y[:split]
X_test, y_test = X[split:], y[split:]

# ===== Xây dựng và huấn luyện mô hình =====
model = build_bigru_cnn_model((X_train.shape[1], X_train.shape[2]))
model.fit(X_train, y_train, epochs=50, batch_size=16, validation_data=(X_test, y_test), verbose=1)

# ===== Dự đoán =====
predictions = model.predict(X_test)

# ===== Giải tỉ lệ để đánh giá =====
predictions = scaler_y.inverse_transform(predictions)
y_test_true = scaler_y.inverse_transform(y_test.reshape(-1, 1))

# ===== Đánh giá hiệu suất mô hình =====
mae = mean_absolute_error(y_test_true, predictions)
mse = mean_squared_error(y_test_true, predictions)
r2 = r2_score(y_test_true, predictions)

print(f"MAE (Mean Absolute Error): {mae:.4f}")
print(f"MSE (Mean Squared Error): {mse:.4f}")
print(f"R² (R-squared score): {r2:.4f}")
# Out:
# Epoch 1/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.2445 - val_loss: 0.0087
# Epoch 2/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0243 - val_loss: 0.0101
# Epoch 3/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0078 - val_loss: 0.0072
# Epoch 4/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0076 - val_loss: 0.0047
# Epoch 5/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0068 - val_loss: 0.0054
# Epoch 6/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0070 - val_loss: 0.0058
# Epoch 7/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0088 - val_loss: 0.0041
# Epoch 8/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0072 - val_loss: 0.0048
# Epoch 9/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0046 - val_loss: 0.0054
# Epoch 10/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0064 - val_loss: 0.0035
# Epoch 11/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0048 - val_loss: 0.0071
# Epoch 12/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0075 - val_loss: 0.0036
# Epoch 13/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0061 - val_loss: 0.0061
# Epoch 14/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0051 - val_loss: 0.0021
# Epoch 15/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0052 - val_loss: 0.0059
# Epoch 16/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0044 - val_loss: 0.0062
# Epoch 17/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0046 - val_loss: 0.0036
# Epoch 18/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0048 - val_loss: 0.0088
# Epoch 19/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0048 - val_loss: 0.0038
# Epoch 20/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0041 - val_loss: 0.0038
# Epoch 21/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0043 - val_loss: 0.0050
# Epoch 22/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0049 - val_loss: 0.0024
# Epoch 23/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0048 - val_loss: 0.0033
# Epoch 24/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0072 - val_loss: 0.0024
# Epoch 25/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0041 - val_loss: 0.0039
# Epoch 26/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0043 - val_loss: 0.0022
# Epoch 27/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0049 - val_loss: 0.0017
# Epoch 28/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0034 - val_loss: 0.0066
# Epoch 29/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0035 - val_loss: 0.0020
# Epoch 30/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0032 - val_loss: 0.0095
# Epoch 31/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0042 - val_loss: 0.0018
# Epoch 32/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0031 - val_loss: 0.0044
# Epoch 33/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0036 - val_loss: 0.0071
# Epoch 34/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0039 - val_loss: 0.0039
# Epoch 35/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0029 - val_loss: 0.0022
# Epoch 36/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0032 - val_loss: 0.0033
# Epoch 37/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0026 - val_loss: 0.0034
# Epoch 38/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0028 - val_loss: 0.0034
# Epoch 39/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0027 - val_loss: 0.0016
# Epoch 40/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0030 - val_loss: 0.0015
# Epoch 41/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0028 - val_loss: 0.0089
# Epoch 42/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0033 - val_loss: 0.0028
# Epoch 43/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0024 - val_loss: 0.0016
# Epoch 44/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 45/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0026 - val_loss: 0.0035
# Epoch 46/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0030 - val_loss: 0.0020
# Epoch 47/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0027 - val_loss: 0.0017
# Epoch 48/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0023 - val_loss: 0.0017
# Epoch 49/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0024 - val_loss: 0.0015
# Epoch 50/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0028 - val_loss: 0.0020
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# MAE (Mean Absolute Error): 3021.8390
# MSE (Mean Squared Error): 14843310.2439
# R² (R-squared score): 0.8364

# %%
#GRU
import numpy as np
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, GRU, Dense, Dropout
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# ===== Hàm xây dựng mô hình GRU đơn thuần =====
def build_gru_model(input_shape):
    inputs = Input(shape=input_shape)
    x = GRU(64, return_sequences=True)(inputs)
    x = GRU(32)(x)
    x = Dense(32, activation='relu')(x)
    x = Dropout(0.2)(x)
    outputs = Dense(1)(x)

    model = Model(inputs=inputs, outputs=outputs)
    model.compile(optimizer='adam', loss='mse')
    return model

# ===== Hàm đọc dữ liệu Bitcoin từ file CSV =====
def load_bitcoin_data_csv(path):
    df = pd.read_csv(path)
    columns_needed = ['Open', 'High', 'Low', 'Close', 'Volume', 'Taker Buy Base Volume', 'Taker Buy Quote Volume']

    for col in columns_needed:
        if col not in df.columns:
            raise ValueError(f"Thiếu cột '{col}' trong dữ liệu.")
    df = df[columns_needed].dropna()
    return df

# ===== Hàm chuẩn bị dữ liệu =====
def prepare_data(df, time_steps=60):
    scaler_X = MinMaxScaler()
    data_X = scaler_X.fit_transform(df)

    scaler_y = MinMaxScaler()
    data_y = scaler_y.fit_transform(df[['Close']])

    X, y = [], []
    for i in range(time_steps, len(df)):
        X.append(data_X[i-time_steps:i])
        y.append(data_y[i])
    return np.array(X), np.array(y), scaler_X, scaler_y

# ===== Load & chuẩn bị dữ liệu =====
path = 'data/BTCUSDT-1d-BINANCE.csv'
data = load_bitcoin_data_csv(path)
X, y, scaler_X, scaler_y = prepare_data(data, time_steps=60)

# ===== Chia train/test =====
split = int(0.75 * len(X))
X_train, y_train = X[:split], y[:split]
X_test, y_test = X[split:], y[split:]

# ===== Xây dựng & huấn luyện GRU đơn thuần =====
model = build_gru_model((X_train.shape[1], X_train.shape[2]))
model.fit(X_train, y_train, epochs=30, batch_size=16, validation_data=(X_test, y_test), verbose=1)

# ===== Dự đoán & đánh giá =====
predictions = model.predict(X_test)
predictions_inv = scaler_y.inverse_transform(predictions)
y_test_inv = scaler_y.inverse_transform(y_test.reshape(-1, 1))

print(f"MAE: {mean_absolute_error(y_test_inv, predictions_inv):.4f}")
print(f"MSE: {mean_squared_error(y_test_inv, predictions_inv):.4f}")
print(f"R2 : {r2_score(y_test_inv, predictions_inv):.4f}")
# Out:
# Epoch 1/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0907 - val_loss: 0.0102
# Epoch 2/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0128 - val_loss: 0.0130
# Epoch 3/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0111 - val_loss: 0.0058
# Epoch 4/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0104 - val_loss: 0.0027
# Epoch 5/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0090 - val_loss: 0.0051
# Epoch 6/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0089 - val_loss: 0.0019
# Epoch 7/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0085 - val_loss: 0.0108
# Epoch 8/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0080 - val_loss: 0.0034
# Epoch 9/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0092 - val_loss: 0.0032
# Epoch 10/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0090 - val_loss: 0.0035
# Epoch 11/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0073 - val_loss: 0.0123
# Epoch 12/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0059 - val_loss: 0.0036
# Epoch 13/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0051 - val_loss: 0.0012
# Epoch 14/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0060 - val_loss: 0.0055
# Epoch 15/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0060 - val_loss: 0.0011
# Epoch 16/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0050 - val_loss: 0.0012
# Epoch 17/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0050 - val_loss: 0.0012
# Epoch 18/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0054 - val_loss: 0.0036
# Epoch 19/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0048 - val_loss: 9.6479e-04
# Epoch 20/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0045 - val_loss: 0.0023
# Epoch 21/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0060 - val_loss: 0.0025
# Epoch 22/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0048 - val_loss: 0.0055
# Epoch 23/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0046 - val_loss: 0.0014
# Epoch 24/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0049 - val_loss: 0.0020
# Epoch 25/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0044 - val_loss: 0.0028
# Epoch 26/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0057 - val_loss: 0.0014
# Epoch 27/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0051 - val_loss: 0.0035
# Epoch 28/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0029 - val_loss: 0.0016
# Epoch 29/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0038 - val_loss: 0.0072
# Epoch 30/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0053 - val_loss: 0.0043
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# MAE: 5141.5393
# MSE: 32426937.6948
# R2 : 0.6425

# %%
#GRU + CNN
# Dự đoán
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Bidirectional, GRU, Conv1D, MaxPooling1D, Dense, Dropout, Flatten
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# ===== Hàm xây dựng mô hình GRU + CNN =====
def build_gru_cnn_model(input_shape):
    inputs = Input(shape=input_shape)
    x = GRU(64, return_sequences=True)(inputs)
    x = GRU(64, return_sequences=True)(x)

    x = Conv1D(filters=32, kernel_size=3, activation='selu', padding='same')(x)
    x = Conv1D(filters=16, kernel_size=3, activation='selu', padding='same')(x)
    x = MaxPooling1D(pool_size=2)(x)

    x = Flatten()(x)
    x = Dense(64, activation='relu')(x)
    x = Dropout(0.2)(x)
    x = Dense(1)(x)

    model = Model(inputs=inputs, outputs=x)
    model.compile(optimizer='adam', loss='mse')
    return model


# ===== Hàm đọc dữ liệu Bitcoin từ file CSV =====
def load_bitcoin_data_csv(path):
    df = pd.read_csv(path)
    columns_needed = ['Open', 'High', 'Low', 'Close', 'Volume', 'Taker Buy Base Volume', 'Taker Buy Quote Volume']
    for col in columns_needed:
        if col not in df.columns:
            raise ValueError(f"Thiếu cột '{col}' trong dữ liệu.")
    df = df[columns_needed].dropna()
    return df

# ===== Hàm chuẩn bị dữ liệu theo chuỗi thời gian =====
def prepare_data(df, time_steps=60):
    scaler_X = MinMaxScaler()
    data_X = scaler_X.fit_transform(df)

    scaler_y = MinMaxScaler()
    data_y = scaler_y.fit_transform(df[['Close']])

    X, y = [], []
    for i in range(time_steps, len(df)):
        X.append(data_X[i-time_steps:i])
        y.append(data_y[i])
    return np.array(X), np.array(y), scaler_X, scaler_y


# ===== Đọc và chuẩn bị dữ liệu =====
path = 'data/BTCUSDT-1d-BINANCE.csv'
data = load_bitcoin_data_csv(path)
X, y, scaler_X, scaler_y = prepare_data(data, time_steps=60)

# ===== Chia dữ liệu train/test =====
split = int(0.75 * len(X))
X_train, y_train = X[:split], y[:split]
X_test, y_test = X[split:], y[split:]

# ===== Xây dựng và huấn luyện mô hình =====
model = build_gru_cnn_model((X_train.shape[1], X_train.shape[2]))
model.fit(X_train, y_train, epochs=30, batch_size=16, validation_data=(X_test, y_test), verbose=1)

# ===== Dự đoán =====
predictions = model.predict(X_test)

# ===== Giải tỉ lệ để đánh giá =====
predictions = scaler_y.inverse_transform(predictions)
y_test_true = scaler_y.inverse_transform(y_test.reshape(-1, 1))

# ===== Đánh giá hiệu suất mô hình =====
mae = mean_absolute_error(y_test_true, predictions)
mse = mean_squared_error(y_test_true, predictions)
r2 = r2_score(y_test_true, predictions)

print(f"MAE (Mean Absolute Error): {mae:.4f}")
print(f"MSE (Mean Squared Error): {mse:.4f}")
print(f"R² (R-squared score): {r2:.4f}")
# Out:
# Epoch 1/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0807 - val_loss: 0.0045
# Epoch 2/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0107 - val_loss: 0.0050
# Epoch 3/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0062 - val_loss: 0.0056
# Epoch 4/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0058 - val_loss: 0.0076
# Epoch 5/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0060 - val_loss: 0.0038
# Epoch 6/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0075 - val_loss: 0.0148
# Epoch 7/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0062 - val_loss: 0.0036
# Epoch 8/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0046 - val_loss: 0.0045
# Epoch 9/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0039 - val_loss: 0.0057
# Epoch 10/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0041 - val_loss: 0.0033
# Epoch 11/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0042 - val_loss: 0.0037
# Epoch 12/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0050 - val_loss: 0.0048
# Epoch 13/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0051 - val_loss: 0.0041
# Epoch 14/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0042 - val_loss: 0.0030
# Epoch 15/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0043 - val_loss: 0.0026
# Epoch 16/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0037 - val_loss: 0.0028
# Epoch 17/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0044 - val_loss: 0.0019
# Epoch 18/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0032 - val_loss: 0.0039
# Epoch 19/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0046 - val_loss: 0.0028
# Epoch 20/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0034 - val_loss: 0.0031
# Epoch 21/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0030 - val_loss: 0.0036
# Epoch 22/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0045 - val_loss: 0.0037
# Epoch 23/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0047 - val_loss: 0.0024
# Epoch 24/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0029 - val_loss: 0.0017
# Epoch 25/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0026 - val_loss: 0.0028
# Epoch 26/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0037 - val_loss: 0.0017
# Epoch 27/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0032 - val_loss: 0.0016
# Epoch 28/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0038 - val_loss: 0.0021
# Epoch 29/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0028 - val_loss: 0.0023
# Epoch 30/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0022 - val_loss: 0.0016
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# MAE (Mean Absolute Error): 2750.4386
# MSE (Mean Squared Error): 12309942.1079
# R² (R-squared score): 0.8643

# %%
# CNN+BiGRU + EarlyStopping + ReduceLR
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Bidirectional, GRU, Conv1D, MaxPooling1D, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# ===== Hàm xây dựng mô hình CNN + BiGRU =====
def build_cnn_bigru_model(input_shape):
    inputs = Input(shape=input_shape)

    # CNN để học pattern ngắn hạn
    x = Conv1D(filters=64, kernel_size=5, activation='selu', padding='same')(inputs)
    x = Conv1D(filters=64, kernel_size=5, activation='selu', padding='same')(x)
    x = MaxPooling1D(pool_size=2)(x)

    # BiGRU để học quan hệ dài hạn
    x = Bidirectional(GRU(64, return_sequences=False))(x)

    # Dense & Dropout
    x = Dense(64, activation='relu')(x)
    x = Dropout(0.2)(x)
    outputs = Dense(1)(x)

    model = Model(inputs=inputs, outputs=outputs)
    model.compile(optimizer='adam', loss='mse')
    return model

# ===== Hàm đọc dữ liệu Bitcoin từ file CSV =====
def load_bitcoin_data_csv(path):
    df = pd.read_csv(path)
    columns_needed = ['Open', 'High', 'Low', 'Close', 'Volume', 'Taker Buy Base Volume', 'Taker Buy Quote Volume']
    for col in columns_needed:
        if col not in df.columns:
            raise ValueError(f"Thiếu cột '{col}' trong dữ liệu.")
    df = df[columns_needed].dropna()
    return df

# ===== Hàm chuẩn bị dữ liệu theo chuỗi thời gian =====
def prepare_data(df, time_steps=60):
    scaler_X = MinMaxScaler()
    data_X = scaler_X.fit_transform(df)

    scaler_y = MinMaxScaler()
    data_y = scaler_y.fit_transform(df[['Close']])

    X, y = [], []
    for i in range(time_steps, len(df)):
        X.append(data_X[i-time_steps:i])
        y.append(data_y[i])
    return np.array(X), np.array(y), scaler_X, scaler_y

# ===== Đọc và chuẩn bị dữ liệu =====
path = 'data/BTCUSDT-1d-BINANCE.csv'
data = load_bitcoin_data_csv(path)
X, y, scaler_X, scaler_y = prepare_data(data, time_steps=60)

# ===== Chia dữ liệu train/test =====
split = int(0.75 * len(X))
X_train, y_train = X[:split], y[:split]
X_test, y_test = X[split:], y[split:]

# ===== Tạo mô hình =====
model = build_cnn_bigru_model((X_train.shape[1], X_train.shape[2]))

# ===== Callbacks: EarlyStopping + ReduceLR =====
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=10,             # chờ 5 epoch không giảm thì dừng
    restore_best_weights=True
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,             # giảm LR 1/2
    patience=3,             # chờ 3 epoch không giảm
    min_lr=1e-6
)

# ===== Huấn luyện mô hình với Callbacks =====
history = model.fit(
    X_train, y_train,
    epochs=50,              # cho số lớn, EarlyStopping tự dừng
    batch_size=64,          # batch_size lớn hơn để nhanh hơn
    validation_data=(X_test, y_test),
    callbacks=[early_stop, reduce_lr],
    verbose=1
)

# ===== Dự đoán =====
predictions = model.predict(X_test)

# ===== Giải tỉ lệ =====
predictions = scaler_y.inverse_transform(predictions)
y_test_true = scaler_y.inverse_transform(y_test.reshape(-1, 1))

# ===== Đánh giá =====
mae = mean_absolute_error(y_test_true, predictions)
mse = mean_squared_error(y_test_true, predictions)
r2 = r2_score(y_test_true, predictions)

print(f"MAE (Mean Absolute Error): {mae:.4f}")
print(f"MSE (Mean Squared Error): {mse:.4f}")
print(f"R² (R-squared score): {r2:.4f}")
# Out:
# Epoch 1/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.1117 - val_loss: 0.0174 - learning_rate: 0.0010
# Epoch 2/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0178 - val_loss: 0.0123 - learning_rate: 0.0010
# Epoch 3/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0123 - val_loss: 0.0101 - learning_rate: 0.0010
# Epoch 4/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0081 - val_loss: 0.0085 - learning_rate: 0.0010
# Epoch 5/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0062 - val_loss: 0.0040 - learning_rate: 0.0010
# Epoch 6/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0043 - val_loss: 0.0038 - learning_rate: 0.0010
# Epoch 7/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0042 - val_loss: 0.0033 - learning_rate: 0.0010
# Epoch 8/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0059 - val_loss: 0.0146 - learning_rate: 0.0010
# Epoch 9/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0058 - val_loss: 0.0108 - learning_rate: 0.0010
# Epoch 10/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0056 - val_loss: 0.0028 - learning_rate: 0.0010
# Epoch 11/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0053 - val_loss: 0.0021 - learning_rate: 0.0010
# Epoch 12/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0057 - val_loss: 0.0019 - learning_rate: 0.0010
# Epoch 13/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0046 - val_loss: 0.0018 - learning_rate: 0.0010
# Epoch 14/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0050 - val_loss: 0.0020 - learning_rate: 0.0010
# Epoch 15/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0041 - val_loss: 0.0065 - learning_rate: 0.0010
# Epoch 16/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0050 - val_loss: 0.0021 - learning_rate: 0.0010
# Epoch 17/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0043 - val_loss: 0.0021 - learning_rate: 5.0000e-04
# Epoch 18/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0043 - val_loss: 0.0020 - learning_rate: 5.0000e-04
# Epoch 19/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0040 - val_loss: 0.0027 - learning_rate: 5.0000e-04
# Epoch 20/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0032 - val_loss: 0.0019 - learning_rate: 2.5000e-04
# Epoch 21/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0044 - val_loss: 0.0021 - learning_rate: 2.5000e-04
# Epoch 22/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0033 - val_loss: 0.0019 - learning_rate: 2.5000e-04
# Epoch 23/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0029 - val_loss: 0.0019 - learning_rate: 1.2500e-04
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# MAE (Mean Absolute Error): 2815.8672
# MSE (Mean Squared Error): 13494277.1725
# R² (R-squared score): 0.8512
